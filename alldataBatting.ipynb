# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('alldatabatting.csv')
df.head()
# Out:
#    Unnamed: 0             Name    runs   balls  fours  sixes          sr
# 0           0  Ruturaj Gaikwad   839.0   635.0   80.0   29.0  132.125984
# 1           1   Faf du Plessis  1640.0  1227.0  155.0   58.0  133.659332
# 2           2    Robin Uthappa   944.0   758.0   85.0   43.0  124.538259
# 3           3        Moeen Ali   666.0   455.0   52.0   42.0  146.373626
# 4           4     Shubman Gill  1417.0  1152.0  137.0   36.0  123.003472

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  240 non-null    int64
#  1   Name        240 non-null    object
#  2   runs        239 non-null    float64
#  3   balls       239 non-null    float64
#  4   fours       239 non-null    float64
#  5   sixes       239 non-null    float64
#  6   sr          239 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.2+ KB

# %%
df1=df.fillna(0.0)
df1
# Out:
#      Unnamed: 0             Name    runs   balls  fours  sixes          sr
# 0             0  Ruturaj Gaikwad   839.0   635.0   80.0   29.0  132.125984
# 1             1   Faf du Plessis  1640.0  1227.0  155.0   58.0  133.659332
# 2             2    Robin Uthappa   944.0   758.0   85.0   43.0  124.538259
# 3             3        Moeen Ali   666.0   455.0   52.0   42.0  146.373626
# 4             4     Shubman Gill  1417.0  1152.0  137.0   36.0  123.003472
# ..          ...              ...     ...     ...    ...    ...         ...
# 235         235      Karn Sharma     0.0     0.0    0.0    0.0    0.000000
# 236         236       Naman Ojha     1.0     4.0    0.0    0.0   25.000000
# 237         237  Prashant Chopra     8.0     6.0    2.0    0.0  133.333333
# 238         238    Javon Searles     8.0     6.0    0.0    1.0  133.333333
# 239         239    Anureet Singh     3.0     4.0    0.0    0.0   75.000000
#
# [240 rows x 7 columns]

# %%
#Remove unneccesary columns
df2= df.drop(columns=["Unnamed: 0"])
df2
# Out:
#                 Name    runs   balls  fours  sixes          sr
# 0    Ruturaj Gaikwad   839.0   635.0   80.0   29.0  132.125984
# 1     Faf du Plessis  1640.0  1227.0  155.0   58.0  133.659332
# 2      Robin Uthappa   944.0   758.0   85.0   43.0  124.538259
# 3          Moeen Ali   666.0   455.0   52.0   42.0  146.373626
# 4       Shubman Gill  1417.0  1152.0  137.0   36.0  123.003472
# ..               ...     ...     ...    ...    ...         ...
# 235      Karn Sharma     0.0     0.0    0.0    0.0    0.000000
# 236       Naman Ojha     1.0     4.0    0.0    0.0   25.000000
# 237  Prashant Chopra     8.0     6.0    2.0    0.0  133.333333
# 238    Javon Searles     8.0     6.0    0.0    1.0  133.333333
# 239    Anureet Singh     3.0     4.0    0.0    0.0   75.000000
#
# [240 rows x 6 columns]

# %%
sns.set_style("whitegrid")

# %%
df2.hist(figsize=(12, 6), bins=10,color='gold', edgecolor="black",)
plt.suptitle("Histogram of Batting Statistics", fontsize=14)
plt.show()

# %%
top_10Players=df.nlargest(10,"runs")
plt.figure(figsize=(10,6))
sns.barplot(x='runs',y='Name',data=top_10Players,palette="RdBu")
plt.title("Total Runs of the top 10 Players")
plt.xlabel("Total Runs")
plt.ylabel("Name of the players")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df["runs"], bins=20, kde=True,color='green')
plt.title("Distribution of Runs Scored")
plt.xlabel("Runs")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter plot: Runs vs Balls Faced
plt.figure(figsize=(10,6))
sns.scatterplot(x=df["balls"], y=df["runs"], hue=df["sr"], palette="inferno", size=df["sr"], sizes=(20, 200))
plt.title("Runs vs Balls Faced (Colored by Strike Rate)")
plt.xlabel("Balls Faced")
plt.ylabel("Runs Scored")
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie([df["fours"].sum(), df["sixes"].sum()], labels=["Fours", "Sixes"], autopct="%1.1f%%", colors=["Gold", "Red"])
plt.title("Proportion of Fours vs Sixes")
plt.show()

# %%
# Filter data for Suryakumar Yadav
player_data = df[df["Name"] == "Suryakumar Yadav"]

# Extract relevant statistics
runs = player_data["runs"].values[0]
fours = player_data["fours"].values[0]
sixes = player_data["sixes"].values[0]
sr = player_data["sr"].values[0]

# Visualization - Bar Chart
stats = ["Runs", "Fours", "Sixes", "Strike Rate"]
values = [runs, fours, sixes, sr]
plt.figure(figsize=(8, 5))
plt.bar(stats, values, color=["skyblue", "lightgreen", "red", "yellow"])
plt.xlabel("Statistics")
plt.ylabel("Values")
plt.title("Batting Performance of Suryakumar Yadav")
plt.show()

# %%
# Filter data for viratkohli Yadav
player_data = df[df["Name"] == "Virat Kohli"]
# Extract relevant statistics
runs = player_data["runs"].values[0]
fours = player_data["fours"].values[0]
sixes = player_data["sixes"].values[0]
sr = player_data["sr"].values[0]

# Visualization - Bar Chart
stats = ["Runs", "Fours", "Sixes", "Strike Rate"]
values = [runs, fours, sixes, sr]

plt.figure(figsize=(8, 5))
plt.bar(stats, values, color=["Silver","Grey","Gold","Lightyellow"])
plt.xlabel("Statistics")
plt.ylabel("Values")
plt.title("Batting Performance of Virat Kohli")
plt.show()
